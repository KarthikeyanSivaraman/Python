# %%
from ClassMF import MultipleFunctions

# %%
MultipleFunctions.eligible()
# Out:
# Enter your gender (Male/Female):  Male
# Enter your age:  20
# NOT ELIGIBLE

# %%
MultipleFunctions.odd_even()
# Out:
# Enter a number:  2
# 2 is Even number
# '2 is Even number'

# %%
MultipleFunctions.subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
MultipleFunctions.percentage()
# Out:
# Enter your Subject1 marks:  98
# Enter your Subject2 marks:  97
# Enter your Subject3 marks:  96
# Enter your Subject4 marks:  95
# Enter your Subject5 marks:  88
# Total: 474
# Percentage: 94.80
# 94.8
